# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/iris.csv')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
d1=data[['SL','SW','PL','PW']].mean()
d1
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.isnull().values.any()
# Out:
# False

# %%
data['Classification'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data['Classification'].head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Classification, dtype: object

# %%
sns.scatterplot(x=data['PL'],y=data['PW'],hue=data['Classification'])
plt.title('Petal Width Vs Petal Length')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
sns.scatterplot(x=data['SL'],y=data['SW'],hue=data['Classification'])
plt.title('Sepal Width Vs Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
sns.histplot(x=data['Classification'])
plt.title("distribution of Iris according to different category")
plt.show()

# %%
sns.countplot(x=data['Classification'])
plt.xlabel('Classification of Iris',fontsize=12)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x=data['SL'],y=data['SW']) 
plt.title('Sepal Width Vs Sepal Length')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x=data['PL'],y=data['PW']) 
plt.title('Petal Width Vs Petal Length')
plt.show()

# %%
sns.boxplot(x=data['Classification'],y=data['PW'])
plt.title('Petal Width of iris in different classification')
plt.show()

# %%
sns.boxplot(x=data['Classification'],y=data['PL'])
plt.title('Petal Length of iris in different classification')
plt.show()

# %%
sns.boxplot(x=data['Classification'],y=data['SW'])
plt.title('Sepal Width of iris in different classification')
plt.show()

# %%
sns.boxplot(x=data['Classification'],y=data['SL'])
plt.title('Sepal Length of iris in different classification')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.boxplot(x=data['SL'],y=data['SW'],hue=data['Classification'])
plt.title('Iris on the basis of Sepal measurement ')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.boxplot(x=data['PL'],y=data['PW'],hue=data['Classification'])
plt.title('Iris on the basis of Petal measurement ')
plt.show()

# %%
sns.relplot(x=data['PL'],y=data['PW'],col=data['Classification'])
plt.show()

# %%
sns.relplot(x=data['SL'],y=data['SW'],row=data['Classification'])
plt.show()

# %%
newdata=data[['PW','PL','Classification']]
sns.pairplot(newdata)
plt.show()

# %%
newdata1=data[['SL','SW','Classification']]
sns.pairplot(newdata1)
plt.show()

# %%
sns.violinplot(x=data['Classification'],y=data['PL'],data=data)
plt.title('Classification on the basis of Petal length')
plt.ylabel('Petal Length')
plt.show()

# %%
sns.violinplot(x=data['Classification'],y=data['PW'],data=data)
plt.title('Classification on the basis of Petal Width')
plt.ylabel('Petal Width')
plt.show()

# %%
sns.violinplot(x=data['Classification'],y=data['SL'],data=data)
plt.title('Classification on the basis of Sepal Length')
plt.ylabel('Sepal Length')
plt.show()

# %%
sns.violinplot(x=data['Classification'],y=data['SW'],data=data)
plt.title('Classification on the basis of Sepal Width')
plt.ylabel('Sepal Width')
plt.show()
